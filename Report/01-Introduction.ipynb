# %% [markdown]
# ## The brief
#
# The brief was to:
#
# * Choose an question to evaluate
# * Learn the parameters of the models
# * Learn the performance of the models
# * Use the results of the models to evaluate the question
#
# We first chose the data that we would work with, as finding a suitable dataset was going to be the main problem. For this we will use a Common Vulnerabilities and Exploits (CVE) database. One of the fields of CVE databases is a description of each CVE entry. We will look into how the nature of the CVEs have changed over time by using topic modelling on the entry descriptions. The Models we will using an LDA model but under different training conditions. As these are unsupervised, it is hard to analyse their performance, however we can look at how they have grouped the terms and evaluate them. To finish we will directly compare the models to see how their results differ.
#
# ## Library requirements

# %%
import sys
import subprocess
reqs = subprocess.check_output([sys.executable,'-m','pip','freeze'])
installed_packages = [r.decode().split('==')[0] for r in reqs.split()]
if not ('pandas' in installed_packages): 
    # !{sys.executable} -m pip install pandas
if not ('sklearn' in installed_packages): 
    # !{sys.executable} -m pip install sklearn
if not ('numpy' in installed_packages): 
    # !{sys.executable} -m pip install numpy
if not ('scipy' in installed_packages): 
    # !{sys.executable} -m pip install scipy   
if not ('seaborn' in installed_packages): 
    # !{sys.executable} -m pip install seaborn 
if not ('matplotlib' in installed_packages): 
    # !{sys.executable} -m pip install matplotlib
# Out:
# Collecting eif
#   Downloading eif-2.0.2.tar.gz (1.6 MB)
#      |████████████████████████████████| 1.6 MB 1.1 MB/s eta 0:00:01
#     ERROR: Command errored out with exit status 1:
#      command: /usr/bin/python3 -c 'import sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-73villsw/eif/setup.py'"'"'; __file__='"'"'/tmp/pip-install-73villsw/eif/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-install-73villsw/eif/pip-egg-info
#          cwd: /tmp/pip-install-73villsw/eif/
#     Complete output (5 lines):
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-73villsw/eif/setup.py", line 4, in <module>
#         from Cython.Distutils import build_ext
#     ModuleNotFoundError: No module named 'Cython'
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# Collecting seaborn
#   Downloading seaborn-0.11.2-py3-none-any.whl (292 kB)
#      |████████████████████████████████| 292 kB 527 kB/s eta 0:00:01
# Requirement already satisfied: pandas>=0.23 in /home/c/.local/lib/python3.8/site-packages (from seaborn) (1.3.4)
# Requirement already satisfied: numpy>=1.15 in /home/c/.local/lib/python3.8/site-packages (from seaborn) (1.21.4)
# Requirement already satisfied: matplotlib>=2.2 in /home/c/.local/lib/python3.8/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: scipy>=1.0 in /home/c/.local/lib/python3.8/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas>=0.23->seaborn) (2.7.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.23->seaborn) (2019.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/c/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/c/.local/lib/python3.8/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3/dist-packages (from matplotlib>=2.2->seaborn) (7.0.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2

# %%
import pandas as pd
import urllib.request
import os
import csv

# %% [markdown]
# ## The data
#
# To obtain this dataset in a convenient format, we will download it and, if necessary, process it into a standard form.
#
# We place data in the raw or processed folder depending on the stage of processing, both of which are in the `data` folder of our root. So our file system will look like this:
#
# * /data
#   * /data/raw
#       * allitems.csv
#   * /data/processed
#       * formatted_df.csv
#       * indepLDAmodels.pickle
#       * topicMap.pickle
#
# ### Get the data

# %%
if not(os.path.exists('../data/raw')):
    os.mkdir('../data/raw')
if not(os.path.exists('../data/processed')):
    os.mkdir('../data/processed')
if not(os.path.exists('../data/raw/allitems.csv.gz')):
    url = 'https://cve.mitre.org/data/downloads/allitems.csv.gz'
    urllib.request.urlretrieve(url, '../data/raw/allitems.csv.gz')
if not(os.path.exists('../data/raw/allitems.csv')):
    col = ["Name","Status","Description","References","Phase","Votes","Comments"]
    data = pd.read_csv('../data/raw/allitems.csv.gz', names = col, encoding='iso8859_15')[10:]
    data.to_csv('../data/raw/allitems.csv')

# %%
df = pd.read_csv("../data/raw/allitems.csv", encoding='iso8859_15').drop(columns = ['Unnamed: 0'])
df
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                   Name     Status  \
# 0        CVE-1999-0001  Candidate
# 1        CVE-1999-0002      Entry
# 2        CVE-1999-0003      Entry
# 3        CVE-1999-0004  Candidate
# 4        CVE-1999-0005      Entry
# ...                ...        ...
# 227233  CVE-2022-24031  Candidate
# 227234  CVE-2022-24032  Candidate
# 227235  CVE-2022-24033  Candidate
# 227236  CVE-2022-24034  Candidate
# 227237  CVE-2022-24035  Candidate
#
#                                               Description  \
# 0       ip_input.c in BSD-derived TCP/IP implementatio...
# 1       Buffer overflow in NFS mountd gives root acces...
# 2       Execute commands as root via buffer overflow i...
# 3       MIME buffer overflow in email clients, e.g. So...
# 4       Arbitrary command execution via IMAP buffer ov...
# ...                                                   ...
# 227233  ** RESERVED ** This candidate has been reserve...
# 227234  ** RESERVED ** This candidate has been reserve...
# 227235  ** RESERVED ** This candidate has been reserve...
# 227236  ** RESERVED ** This candidate has been reserve...
# 227237  ** RESERVED ** This candidate has been reserve...
#
#                                                References  \
# 0       BUGTRAQ:19981223 Re: CERT Advisory CA-98.13 - ...
# 1       BID:121   |   URL:http://www.securityfocus.com...
# 2       BID:122   |   URL:http://www.securityfocus.com...
# 3       CERT:CA-98.10.mime_buffer_overflows   |   MS:M...
# 4       BID:130   |   URL:http://www.securityfocus.com...
# ...                                                   ...
# 227233                                                NaN
# 227234                                                NaN
# 227235                                                NaN
# 227236                                                NaN
# 227237                                                NaN
#
#                       Phase  \
# 0       Modified (20051217)
# 1                       NaN
# 2                       NaN
# 3       Modified (19990621)
# 4                       NaN
# ...                     ...
# 227233  Assigned (20220126)
# 227234  Assigned (20220126)
# 227235  Assigned (20220126)
# 227236  Assigned (20220126)
# 227237  Assigned (20220126)
#
#                                                     Votes  \
# 0          MODIFY(1) Frech  |     NOOP(2) Northcutt, W...
# 1                                                     NaN
# 2                                                     NaN
# 3          ACCEPT(8) Baker, Cole, Collins, Dik, Landfi...
# 4                                                     NaN
# ...                                                   ...
# 227233                  None (candidate not yet proposed)
# 227234                  None (candidate not yet proposed)
# 227235                  None (candidate not yet proposed)
# 227236                  None (candidate not yet proposed)
# 227237                  None (candidate not yet proposed)
#
#                                                  Comments
# 0       Christey> A Bugtraq posting indicates that the...
# 1                                                     NaN
# 2                                                     NaN
# 3       Frech> Extremely minor, but I believe e-mail i...
# 4                                                     NaN
# ...                                                   ...
# 227233                                                NaN
# 227234                                                NaN
# 227235                                                NaN
# 227236                                                NaN
# 227237                                                NaN
#
# [227238 rows x 7 columns]
